# %%
# !pip install -q -U google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.4/718.4 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.9/234.9 kB 12.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.43.0, but you have google-auth 2.47.0 which is incompatible.

# %%
import os
os.environ["GEMINI_API_KEY"] = "PASTE_KEY_HERE"

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns patterns from data to make predictions.

# %%
from google import genai

client = genai.Client()

result = client.models.embed_content(
        model="gemini-embedding-001",
        contents="What is the meaning of life?"
)

print(result.embeddings)
# Out:
# [ContentEmbedding(
#   values=[
#     -0.022374554,
#     -0.004560777,
#     0.013309286,
#     -0.0545072,
#     -0.02090443,
#     <... 3067 more items ...>,
#   ]
# )]

# %%
from google import genai
from google.genai import types
import wave

# Set up the wave file to save the output:
def wave_file(filename, pcm, channels=1, rate=24000, sample_width=2):
   with wave.open(filename, "wb") as wf:
      wf.setnchannels(channels)
      wf.setsampwidth(sample_width)
      wf.setframerate(rate)
      wf.writeframes(pcm)

client = genai.Client()

response = client.models.generate_content(
   model="gemini-2.5-flash-preview-tts",
   contents="Say cheerfully: Have a wonderful day!",
   config=types.GenerateContentConfig(
      response_modalities=["AUDIO"],
      speech_config=types.SpeechConfig(
         voice_config=types.VoiceConfig(
            prebuilt_voice_config=types.PrebuiltVoiceConfig(
               voice_name='Kore',
            )
         )
      ),
   )
)

data = response.candidates[0].content.parts[0].inline_data.data

file_name='out.wav'
wave_file(file_name, data) # Saves the file to current directory

# %%
from IPython.display import Audio, display

display(Audio("out.wav"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google import genai
from google.genai import types
import httpx

client = genai.Client()

doc_url = "https://discovery.ucl.ac.uk/id/eprint/10089234/1/343019_3_art_0_py4t4l_convrt.pdf"

# Retrieve and encode the PDF byte
doc_data = httpx.get(doc_url).content

prompt = "Summarize this document"
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=[
        types.Part.from_bytes(
            data=doc_data,
            mime_type='application/pdf',
        ),
        prompt
    ]
)

print(response.text)
# Out:
# This document describes **AlphaFold**, a deep-learning-based system developed by DeepMind for predicting the three-dimensional structure of proteins from their amino acid sequences.
#
# ### **Overview**
# Protein structure prediction is a major challenge in biology because a protein's function is determined by its 3D shape. While experimental methods are slow and difficult, AlphaFold represents a significant leap in computational accuracy, particularly for proteins where no similar known structures (homologs) exist.
#
# ### **Key Innovations**
# The core shift introduced by AlphaFold is moving from predicting binary "contacts" between amino acid residues to predicting **continuous distance distributions**.
# *   **Distance Distributions (Distograms):** Instead of just predicting if two residues are touching, the system predicts a discrete probability distribution for the distances between all pairs of residues.
# *   **Deep Neural Network:** AlphaFold uses a deep convolutional neural network (with 220 residual convolution blocks) trained on known protein structures from the Protein Data Bank (PDB).
# *   **Protein-Specific Potential:** The distance and torsion angle predictions are combined into a mathematical "potential" (an energy landscape).
# *   **Gradient Descent Optimization:** Unlike previous methods that required complex stochastic sampling (like simulated annealing), AlphaFold's structures can be realized by minimizing this potential using a simple gradient descent algorithm (L-BFGS).
#
# ### **Performance in CASP13**
# AlphaFold was entered into the 13th Critical Assessment of Protein Structure Prediction (CASP13), a biennial "blind" global competition.
# *   **Results:** AlphaFold placed first, significantly outperforming other groups. It achieved high-accuracy structures (TM-scores of 0.7 or higher) for **24 out of 43** "free modelling" domains, compared to only 14 out of 43 for the next-best method.
# *   **Accuracy:** It demonstrated unprecedented accuracy in predicting previously unknown folds and even performed well on "template-based" modeling without actually using templates.
#
# ### **Biological Significance**
# The authors highlight several areas where AlphaFold's improved accuracy provides biological value:
# *   **Functional Insights:** Understanding how proteins function and why they malfunction in diseases.
# *   **Interface Prediction:** Accurately modeling how proteins interact with each other (heterodimers).
# *   **Drug Discovery:** Better prediction of ligand-binding pockets, which is crucial for designing new medicines.
# *   **Crystallography:** Assisting in "phasing" for X-ray crystallography via improved molecular replacement.
#
# ### **Conclusion**
# The paper concludes that deep learning, specifically through the prediction of inter-residue distances, provides a powerful and efficient path toward solving the protein-folding problem, matching or exceeding the performance of traditional methods that rely on structural templates.
